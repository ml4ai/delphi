# %% [markdown]
# # AutoMATES Model Extraction Example

# %% [markdown]
# This tutorial demonstrates how to create a grounded function network from a Fortran source file and supporting documents.

# %%
from IPython.core.display import Image

from delphi.GrFN.networks import GroundedFunctionNetwork
import delphi.GrFN.linking as linking
from notebook_utils import run_TR_pipeline

fortran_filename = "files/SIR-simple.f"
G = GroundedFunctionNetwork.from_fortran_file(fortran_filename, save_file=True)

# View the extracted GrFN
Image(G.to_agraph().draw(format="png", prog="dot"), retina=True)
# Out:
# *** ALL OUTPUT FILES LIVE IN [.]

# %% [markdown]
# We can also view the CAG graph of the GrFN. The CAG shows the directed releationships between variables in the GrFN

# %%
CAG = G.to_CAG_agraph()
Image(CAG.draw(format="png", prog="dot"), retina=True)

# %%
G = run_TR_pipeline("SIR-simple_GrFN")
tables = linking.make_link_tables(G)
linking.print_table_data(tables)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-852790ccc1a5> in <module>
# ----> 1 G = run_TR_pipeline("SIR-simple_GrFN")
#       2 tables = linking.make_link_tables(G)
#       3 linking.print_table_data(tables)
#
# ~/Documents/repos/delphi/notebooks/GrFN/notebook_utils.py in run_TR_pipeline(basename)
#      22     if os.path.isfile(tr_json_path):
#      23         os.rename(tr_json_path, norm_json_path)
# ---> 24     grfn = json.load(open(norm_json_path, "r"))
#      25     return grfn
#
# FileNotFoundError: [Errno 2] No such file or directory: 'files/SIR-simple_GrFN.json'
